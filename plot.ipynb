# %%
import matplotlib.pyplot as plt

# %%
hill_climbing = {203.98:2072, 76.42:1593}
tabu = {228.55:2072, 80.88:1593}
cuckoo = {6.38:2072, 3.07:1593}
cuckoo_tabu = {23.93:2072, 17.93:1593}

# %%
plt.figure(dpi = 100)
plt.title('Performance of Algorithms based on different number of spaces to be allocated')
plt.plot(list(hill_climbing.keys()), list(hill_climbing.values()))
plt.plot(list(tabu.keys()), list(tabu.values()))
plt.plot(list(cuckoo.keys()), list(cuckoo.values()))
plt.plot(list(cuckoo_tabu.keys()), list(cuckoo_tabu.values()))
plt.xlabel("Time Taken")
plt.ylabel("Number of total space")
plt.legend(['Hill climbing', 'Tabu Search', 'Cuckoo', 'Cuckoo_Tabu(Hybrid)'])
plt.show()

# %%
plt.figure(dpi = 120)
plt.title('Performance of Algorithms based on different number of spaces to be allocated')
plt.xticks(list(range(0, 300, 20)))
plt.plot(list(hill_climbing.keys()), list(hill_climbing.values()))
plt.plot(list(tabu.keys()), list(tabu.values()))
plt.plot(list(cuckoo.keys()), list(cuckoo.values()))
plt.plot(list(cuckoo_tabu.keys()), list(cuckoo_tabu.values()))
plt.xlabel("Time Taken")
plt.ylabel("Number of total space")
plt.legend(['Hill climbing', 'Tabu Search', 'Cuckoo', 'Cuckoo_Tabu(Hybrid)'])
plt.show()
